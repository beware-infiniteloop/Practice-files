# %%
import pandas as pd

# %% [markdown]
# # PANDAS PRACTICE

# %%
ds=pd.Series([91,2,3])
ds
# Out:
# 0    91
# 1     2
# 2     3
# dtype: int64

# %%
print(type(ds))
new_l=ds.tolist()
print(type(new_l))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'list'>

# %%
# COMPARING TWO PANDA SERIES
ds1=pd.Series([2,3,42,3])
ds2=pd.Series([2,3,49,9])
print("Checking equality")
print(ds1==ds2)
print("Checking greater than:")
print(ds1>ds2)
print("Checking less than:")
print(ds2>ds1)
# Out:
# Checking equality
# 0     True
# 1     True
# 2    False
# 3    False
# dtype: bool
# Checking greater than:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool
# Checking less than:
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
#convert dictionary to panda series
d={1:"lol",2:"kol",3:"pop"}
ds=pd.Series(d)
ds
# Out:
# 1    lol
# 2    kol
# 3    pop
# dtype: object

# %%
s1 = pd.Series([100, '200', 'python', '300.12', [1,2]])
print("Original Data Series:")
print(s1)
print("Change the said data type to numeric:")
s2 = pd.to_numeric(s1, errors='coerce')
print(s2)
# Out:
# Original Data Series:
# 0       100
# 1       200
# 2    python
# 3    300.12
# 4    [1, 2]
# dtype: object
# Change the said data type to numeric:
# 0    100.00
# 1    200.00
# 2       NaN
# 3    300.12
# 4       NaN
# dtype: float64

# %%
date_strings = ['2023-04-14', '04/01/2024', '14-April-2024', 'not a date']
dates = pd.to_datetime(date_strings, errors='coerce')
print(dates)
# Out:
# DatetimeIndex(['2023-04-14', 'NaT', 'NaT', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
d = {'col1': [1, 2, 3, 4, 7, 11], 'col2': [4, 5, 6, 9, 5, 0], 'col3': [7, 5, 8, 12, 1, 11]}
df = pd.DataFrame(data=d)

print("Original DataFrame")
print(df)

s1 = df.iloc[:, 0]
print(s1)
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     5
# 2     3     6     8
# 3     4     9    12
# 4     7     5     1
# 5    11     0    11
# 0     1
# 1     2
# 2     3
# 3     4
# 4     7
# 5    11
# Name: col1, dtype: int64

# %%
ds=pd.read_csv(r'C:\Users\Arup Bhattacharjee\Downloads\panda csv files\nyc_weather.csv')
ds
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
ds['Temperature'].max()
# Out:
# 50

# %%
ds['EST'][ds['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
ds['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %%
ds.fillna(0,inplace=True)
ds['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903

# %%
#Dataframe is most commonly used object in pandas. It is a table like datastructure containing rows and columns similar to excel spreadsheet
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}
df=pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
rows,columns=df.shape
print(rows)
print(columns)
# Out:
# 6
# 4

# %%
df.head(1)
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain

# %%
df.tail(1)
# Out:
#         day  temperature  windspeed  event
# 5  1/6/2017           31          2  Sunny

# %%
df[2:4]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df['event']
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %%
type(df['event'])
# Out:
# pandas.core.series.Series

# %%
df[['event','day','temperature']]
# Out:
#    event       day  temperature
# 0   Rain  1/1/2017           32
# 1  Sunny  1/2/2017           35
# 2   Snow  1/3/2017           28
# 3   Snow  1/4/2017           24
# 4   Rain  1/5/2017           32
# 5  Sunny  1/6/2017           31

# %%
df['temperature'].std()
# Out:
# 3.8297084310253524

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
df[df['temperature']==df['temperature'].max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df['day'][df['temperature']==df['temperature'].max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %%
df[['day','temperature']][df['temperature']==df['temperature'].max()] #WARNING give columns as list
# Out:
#         day  temperature
# 1  1/2/2017           35

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.set_index('day')
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df.set_index('temperature')
# Out:
#                   day  windspeed  event
# temperature
# 32           1/1/2017          6   Rain
# 35           1/2/2017          7  Sunny
# 28           1/3/2017          2   Snow
# 24           1/4/2017          7   Snow
# 32           1/5/2017          4   Rain
# 31           1/6/2017          2  Sunny

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df.loc['1/1/2017']
# Out:
# temperature      32
# windspeed         6
# event          Rain
# Name: 1/1/2017, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    index       day  temperature  windspeed  event
# 0      0  1/1/2017           32          6   Rain
# 1      1  1/2/2017           35          7  Sunny
# 2      2  1/3/2017           28          2   Snow
# 3      3  1/4/2017           24          7   Snow
# 4      4  1/5/2017           32          4   Rain
# 5      5  1/6/2017           31          2  Sunny

# %%
df.set_index('event',inplace=True)

# %%
df
# Out:
#        index       day  temperature  windspeed
# event
# Rain       0  1/1/2017           32          6
# Sunny      1  1/2/2017           35          7
# Snow       2  1/3/2017           28          2
# Snow       3  1/4/2017           24          7
# Rain       4  1/5/2017           32          4
# Sunny      5  1/6/2017           31          2

# %%
df.loc['Snow']
# Out:
#        index       day  temperature  windspeed
# event
# Snow       2  1/3/2017           28          2
# Snow       3  1/4/2017           24          7

# %%
data = [
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',35,7,'Sunny'),
    ('1/3/2017',28,2,'Snow')
]
df = pd.DataFrame(data=data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# ## read write excel csv file

# %%
df=pd.read_csv(r'C:\Users\Arup Bhattacharjee\Downloads\stock_data.csv')
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df=pd.read_csv(r'C:\Users\Arup Bhattacharjee\Downloads\stock_data.csv',skiprows=1)
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
df=pd.read_csv(r'C:\Users\Arup Bhattacharjee\Downloads\stock_data.csv',header=1)
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
df=pd.read_csv(r'C:\Users\Arup Bhattacharjee\Downloads\stock_data.csv',header=None)
df
# Out:
#          0              1        2      3              4
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %%
df = pd.read_csv(r'C:\Users\Arup Bhattacharjee\Downloads\stock_data.csv', header=None, names = ["ticker","eps","revenue","people"])
df
# Out:
#                 ticker      eps revenue         people
# tickers            eps  revenue   price         people
# GOOGL            27.82       87     845     larry page
# WMT               4.61      484      65           n.a.
# MSFT                -1       85      64     bill gates
# RIL      not available       50    1023  mukesh ambani
# TATA               5.6       -1    n.a.     ratan tata

# %%
df = pd.read_csv(r'C:\Users\Arup Bhattacharjee\Downloads\stock_data.csv',skiprows=1, names = ["Ticker","eps","revenue","people"])
df
# Out:
#               Ticker  eps revenue         people
# GOOGL          27.82   87     845     larry page
# WMT             4.61  484      65           n.a.
# MSFT              -1   85      64     bill gates
# RIL    not available   50    1023  mukesh ambani
# TATA             5.6   -1    n.a.     ratan tata

# %%
df = pd.read_csv(r'C:\Users\Arup Bhattacharjee\Downloads\stock_data.csv',  nrows=2)
df
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.

# %%
df = pd.read_csv(r'C:\Users\Arup Bhattacharjee\Downloads\stock_data.csv', na_values=["n.a.", "not available"])
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
df = pd.read_csv(r'C:\Users\Arup Bhattacharjee\Downloads\stock_data.csv', na_values=["n.a.", "not available",'eps'])
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
df = pd.read_csv(r'C:\Users\Arup Bhattacharjee\Downloads\stock_data.csv',  na_values={
        'eps': ['not available'],
        'revenue': -1,
        'people': ['not available','n.a.']
    })
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
df.to_csv(r"C:\Users\Arup Bhattacharjee\Downloads\new.csv")

# %%
df.to_csv(r"C:\Users\Arup Bhattacharjee\Downloads\new2.csv", index=False)

# %%
df.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %%
df.to_csv(r"C:\Users\Arup Bhattacharjee\Downloads\new2.csv",header=False)

# %%
pd.read_csv(r"C:\Users\Arup Bhattacharjee\Downloads\new2.csv")
# Out:
#    0 GOOGL  27.82   87.0   845     larry page
# 0  1   WMT   4.61  484.0    65            NaN
# 1  2  MSFT  -1.00   85.0    64     bill gates
# 2  3  RIL     NaN   50.0  1023  mukesh ambani
# 3  4  TATA   5.60    NaN  n.a.     ratan tata

# %%
df.to_csv(r"C:\Users\Arup Bhattacharjee\Downloads\new2.csv", columns=["tickers","price"], index=False)

# %%
pd.read_csv(r"C:\Users\Arup Bhattacharjee\Downloads\new2.csv")
# Out:
#   tickers price
# 0   GOOGL   845
# 1     WMT    65
# 2    MSFT    64
# 3    RIL   1023
# 4    TATA  n.a.

# %%
df=pd.read_excel(r"C:\Users\Arup Bhattacharjee\Downloads\stock_data.xlsx", "Sheet1")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
pip install openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/250.0 kB ? eta -:--:--
#    ------------------ --------------------- 112.6/250.0 kB 1.3 MB/s eta 0:00:01
#    ------------------------------- -------- 194.6/250.0 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 250.0/250.0 kB 1.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_excel(r"C:\Users\Arup Bhattacharjee\Downloads\stock_data.xlsx", "Sheet1")

# %%
def convert_people(cell):
    if cell=="n.a.":
        return 'Sam Waltman'
    return cell
df=pd.read_excel(r"C:\Users\Arup Bhattacharjee\Downloads\stock_data.xlsx", "Sheet1",converters={"people":convert_people})

# %%
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65    Sam Waltman
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
def convert_people_cell(cell):
    if cell=="n.a.":
        return 'Sam Walton'
    return cell

def convert_price_cell(cell):
    if cell=="n.a.":
        return 50
    return cell
    
df = pd.read_excel(r"C:\Users\Arup Bhattacharjee\Downloads\stock_data.xlsx","Sheet1", converters= {
        'people': convert_people_cell,
        'price': convert_price_cell
    })
df
# Out:
#   tickers            eps  revenue  price         people
# 0   GOOGL          27.82       87    845     larry page
# 1     WMT           4.61      484     65     Sam Walton
# 2    MSFT             -1       85     64     bill gates
# 3    RIL   not available       50   1023  mukesh ambani
# 4    TATA            5.6       -1     50     ratan tata

# %%
df.to_excel(r"C:\Users\Arup Bhattacharjee\Downloads\new2.xlsx",startrow=2,startcol=3)

# %%
df_stocks = pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    'price': [845, 65, 64 ],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

df_weather =  pd.DataFrame({
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']
})

# %%
with pd.ExcelWriter(r'C:\Users\Arup Bhattacharjee\Downloads\stocks_weather1.xlsx') as writer:
    df_stocks.to_excel(writer, sheet_name="stocks")
    df_weather.to_excel(writer, sheet_name="weather")

# %%
df=pd.read_excel(r'C:\Users\Arup Bhattacharjee\Downloads\stocks_weather1.xlsx',sheet_name="stocks")
df
# Out:
#    Unnamed: 0 tickers  price     pe    eps
# 0           0   GOOGL    845  30.37  27.82
# 1           1     WMT     65  14.26   4.61
# 2           2    MSFT     64  30.97   2.12

# %%
df=pd.read_excel(r'C:\Users\Arup Bhattacharjee\Downloads\stocks_weather1.xlsx',sheet_name="weather")
df
# Out:
#    Unnamed: 0       day  temperature  event
# 0           0  1/1/2017           32   Rain
# 1           1  1/2/2017           35  Sunny
# 2           2  1/3/2017           28   Snow

# %% [markdown]
# ## Handle Missing Data: fillna, dropna, interpolate

# %%
df = pd.read_csv(r"C:\Users\Arup Bhattacharjee\Downloads\weather_data.csv", parse_dates=["day"])

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df.set_index("day",inplace=True)

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna(0)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        9.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08          0.0        0.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna({'temperature':0,
                 'windspeed':0,
                 'event':'no event'})
new_df
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        9.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  no event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08          0.0        0.0     Sunny
# 2017-01-09          0.0        0.0  no event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %%
new_df=df.fillna(method='ffill')
new_df
# Out:
# C:\Users\Arup Bhattacharjee\AppData\Local\Temp\ipykernel_4812\1317224737.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df=df.fillna(method='ffill')
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        7.0   Sunny
# 2017-01-09         32.0        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna(method="bfill")
new_df
# Out:
# C:\Users\Arup Bhattacharjee\AppData\Local\Temp\ipykernel_4812\3832046755.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df=df.fillna(method="bfill")
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         28.0        9.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0        8.0    Rain
# 2017-01-08         34.0        8.0   Sunny
# 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna(method="ffill",limit=1)
new_df
# Out:
# C:\Users\Arup Bhattacharjee\AppData\Local\Temp\ipykernel_4812\1893442430.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df=df.fillna(method="ffill",limit=1)
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        NaN   Sunny
# 2017-01-09          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.interpolate()
new_df
# Out:
# C:\Users\Arup Bhattacharjee\AppData\Local\Temp\ipykernel_4812\1725489846.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df=df.interpolate()
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    30.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
new_df=df.interpolate(method='time')
new_df
# Out:
# C:\Users\Arup Bhattacharjee\AppData\Local\Temp\ipykernel_4812\2394835608.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df=df.interpolate(method='time')
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
new_df=df.dropna()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(how='all')
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(thresh=1)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(thresh=2)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-07         32.0        NaN    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(thresh=3)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
#insert misssing dates in df
dt = pd.date_range("01-01-2017","01-11-2017")
idx = pd.DatetimeIndex(dt)
df = df.reindex(idx)
df
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
print("matplotlib")
# Out:
# matplotlib

# %%
import matplotlib

# %%
# %matplotlib inline
df.temperature.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ## Handle Missing Data: replace function

# %%
df
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Arup Bhattacharjee\Downloads\weather_data2.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
new_df = df.replace(-99999, value=np.NaN)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
new_df = df.replace(to_replace=[-99999,-88888], value=0)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017            0          7  Sunny
# 2  1/3/2017           28          0   Snow
# 3  1/4/2017            0          7      0
# 4  1/5/2017           32          0   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
new_df = df.replace({
        'temperature': -99999,
        'windspeed': -99999,
        'event': '0'
    }, np.nan)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %%
new_df = df.replace({
        -99999: np.nan,
        'no event': 'Sunny',
    })
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
df=pd.read_csv(r'C:\Users\Arup Bhattacharjee\Downloads\weather_data2.csv')
df
# Out:
#           day  temperature windspeed  event
# 0  01-01-2017           32      6mph   Rain
# 1  01-02-2017       -99999      7mph  Sunny
# 2  01-03-2017           28    -99999   Snow
# 3  01-04-2017       -99999         7      0
# 4  01-05-2017           32    -99999   Rain
# 5  01-06-2017           31         2  Sunny
# 6  01-06-2017           34         5      0

# %%
new_df = df.replace({'temperature': '[A-Za-z]', 'windspeed': '[a-z]'},'', regex=True) 
new_df
# Out:
#           day  temperature windspeed  event
# 0  01-01-2017           32         6   Rain
# 1  01-02-2017       -99999         7  Sunny
# 2  01-03-2017           28    -99999   Snow
# 3  01-04-2017       -99999         7      0
# 4  01-05-2017           32    -99999   Rain
# 5  01-06-2017           31         2  Sunny
# 6  01-06-2017           34         5      0

# %%
new_df = df.replace('[A-Za-z]','', regex=True) 
new_df
# Out:
#           day  temperature windspeed event
# 0  01-01-2017           32         6
# 1  01-02-2017       -99999         7
# 2  01-03-2017           28    -99999
# 3  01-04-2017       -99999         7     0
# 4  01-05-2017           32    -99999
# 5  01-06-2017           31         2
# 6  01-06-2017           34         5     0

# %%
df = pd.DataFrame({
    'score': ['exceptional','average', 'good', 'poor', 'average', 'exceptional'],
    'student': ['rob', 'maya', 'parthiv', 'tom', 'julian', 'erica']
})
df
# Out:
#          score  student
# 0  exceptional      rob
# 1      average     maya
# 2         good  parthiv
# 3         poor      tom
# 4      average   julian
# 5  exceptional    erica

# %%
df.replace(['poor', 'average', 'good', 'exceptional'], [1,2,3,4])
# Out:
# C:\Users\Arup Bhattacharjee\AppData\Local\Temp\ipykernel_4812\4027045839.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(['poor', 'average', 'good', 'exceptional'], [1,2,3,4])
#    score  student
# 0      4      rob
# 1      2     maya
# 2      3  parthiv
# 3      1      tom
# 4      2   julian
# 5      4    erica

# %% [markdown]
# ## Group By (Split Apply Combine)

# %%
df=pd.read_csv(r'C:\Users\Arup Bhattacharjee\Downloads\weather_by_cities.csv')
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
gr=df.groupby('city')
gr

# %%
for city,city_df in gr:
    print(city)
    print(city_df)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
gr.get_group('mumbai')
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %%
gr.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
gr.min()
# Out:
#                day  temperature  windspeed   event
# city
# mumbai    1/1/2017           85          5     Fog
# new york  1/1/2017           28          6    Rain
# paris     1/1/2017           42          8  Cloudy

# %%
gr.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
gr.size()
# Out:
# city
# mumbai      4
# new york    4
# paris       4
# dtype: int64

# %%
gr.count()
# Out:
#           day  temperature  windspeed  event
# city
# mumbai      4            4          4      4
# new york    4            4          4      4
# paris       4            4          4      4

# %%
# %matplotlib inline
gr.plot()
# Out:
# city
# mumbai      Axes(0.125,0.11;0.775x0.77)
# new york    Axes(0.125,0.11;0.775x0.77)
# paris       Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
def grouper(df, idx, col):
    if 80 <= df[col].loc[idx] <= 90:
        return '80-90'
    elif 50 <= df[col].loc[idx] <= 60:
        return '50-60'
    else:
        return 'others'
g = df.groupby(lambda x: grouper(df, x, 'temperature'))
for key, d in g:
    print("Group by Key: {}\n".format(key))
    print(d)
# Out:
# Group by Key: 50-60
#
#          day   city  temperature  windspeed   event
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# Group by Key: 80-90
#
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# Group by Key: others
#
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 11  1/4/2017     paris           42         10  Cloudy

# %%
india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df = pd.concat([india_weather, us_weather])
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df = pd.concat([india_weather, us_weather],ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
df = pd.concat([india_weather, us_weather], keys=["india", "us"])
df
# Out:
#              city  temperature  humidity
# india 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# us    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
df.loc["us"]
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
temperature_df = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
}, index=[0,1,2]) #give index to match cities
temperature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df = pd.DataFrame({
    "city": ["delhi","mumbai"],
    "windspeed": [7,12],
}, index=[1,0])
windspeed_df
# Out:
#      city  windspeed
# 1   delhi          7
# 0  mumbai         12

# %%
df = pd.concat([temperature_df,windspeed_df])
df
# Out:
#        city  temperature  windspeed
# 0    mumbai         32.0        NaN
# 1     delhi         45.0        NaN
# 2  banglore         30.0        NaN
# 1     delhi          NaN        7.0
# 0    mumbai          NaN       12.0

# %%
df = pd.concat([temperature_df,windspeed_df],axis=1)
df
# Out:
#        city  temperature    city  windspeed
# 0    mumbai           32  mumbai       12.0
# 1     delhi           45   delhi        7.0
# 2  banglore           30     NaN        NaN

# %%
s = pd.Series(["Humid","Dry","Rain"], name="event")
s
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: event, dtype: object

# %%
df = pd.concat([temperature_df,s],axis=1)
df
# Out:
#        city  temperature  event
# 0    mumbai           32  Humid
# 1     delhi           45    Dry
# 2  banglore           30   Rain

# %% [markdown]
# ## Merge Dataframes

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %%
df3 = pd.merge(df1, df2)
df3
#parameters of merge: left
#right
#how
#on
#left_on
#right_on
#left_index
#right_index
#sort
#suffixes
#copy
#indicator
#validate
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35, 38],
})
df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "humidity": [65,68,71],
})
df2
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        71

# %%
df1.join(df2,lsuffix='_l', rsuffix='_r')
# Out:
#       city_l  temperature     city_r  humidity
# 0   new york           21    chicago      65.0
# 1    chicago           14   new york      68.0
# 2    orlando           35  san diego      71.0
# 3  baltimore           38        NaN       NaN

# %%
df3=pd.merge(df1,df2,on="city",how="inner")
df3
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65

# %%
df3=pd.merge(df1,df2,on="city",how="outer")
df3
# Out:
#         city  temperature  humidity
# 0  baltimore         38.0       NaN
# 1    chicago         14.0      65.0
# 2   new york         21.0      68.0
# 3    orlando         35.0       NaN
# 4  san diego          NaN      71.0

# %%
df3=pd.merge(df1,df2,on="city",how="left")
df3
# Out:
#         city  temperature  humidity
# 0   new york           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           38       NaN

# %%
df3=pd.merge(df1,df2,on="city",how="right")
df3
# Out:
#         city  temperature  humidity
# 0    chicago         14.0        65
# 1   new york         21.0        68
# 2  san diego          NaN        71

# %%
df3=pd.merge(df1,df2,on="city",how="outer",indicator=True)
df3
# Out:
#         city  temperature  humidity      _merge
# 0  baltimore         38.0       NaN   left_only
# 1    chicago         14.0      65.0        both
# 2   new york         21.0      68.0        both
# 3    orlando         35.0       NaN   left_only
# 4  san diego          NaN      71.0  right_only

# %% [markdown]
# ### suffixes

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35,38],
    "humidity": [65,68,71, 75]
})
df1
# Out:
#         city  temperature  humidity
# 0   new york           21        65
# 1    chicago           14        68
# 2    orlando           35        71
# 3  baltimore           38        75

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "temperature": [21,14,35],
    "humidity": [65,68,71]
})
df2
# Out:
#         city  temperature  humidity
# 0    chicago           21        65
# 1   new york           14        68
# 2  san diego           35        71

# %%
df3= pd.merge(df1,df2,on="city",how="outer", suffixes=(' first',' second'))
df3
# Out:
#         city  temperature first  humidity first  temperature second  \
# 0  baltimore               38.0            75.0                 NaN
# 1    chicago               14.0            68.0                21.0
# 2   new york               21.0            65.0                14.0
# 3    orlando               35.0            71.0                 NaN
# 4  san diego                NaN             NaN                35.0
#
#    humidity second
# 0              NaN
# 1             65.0
# 2             68.0
# 3              NaN
# 4             71.0

# %%
df = pd.read_csv(r"C:\Users\Arup Bhattacharjee\Downloads\weather.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
dict=df.to_dict()
dict
# Out:
# {'date': {0: '5/1/2017',
#   1: '5/2/2017',
#   2: '5/3/2017',
#   3: '5/1/2017',
#   4: '5/2/2017',
#   5: '5/3/2017',
#   6: '5/1/2017',
#   7: '5/2/2017',
#   8: '5/3/2017'},
#  'city': {0: 'new york',
#   1: 'new york',
#   2: 'new york',
#   3: 'mumbai',
#   4: 'mumbai',
#   5: 'mumbai',
#   6: 'beijing',
#   7: 'beijing',
#   8: 'beijing'},
#  'temperature': {0: 65,
#   1: 66,
#   2: 68,
#   3: 75,
#   4: 78,
#   5: 82,
#   6: 80,
#   7: 77,
#   8: 79},
#  'humidity': {0: 56, 1: 58, 2: 60, 3: 80, 4: 83, 5: 85, 6: 26, 7: 30, 8: 35}}

# %%
df.pivot(index='city',columns='date',values="humidity")
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %%
df.pivot_table(index="city",columns="date",values="humidity")
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing       26.0      30.0      35.0
# mumbai        80.0      83.0      85.0
# new york      56.0      58.0      60.0
